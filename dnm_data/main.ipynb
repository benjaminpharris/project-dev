# %%
# Imports

    # system
import os, sys, tarfile, dotenv, time, datetime, re

    # data
import pandas as pd  
import numpy as np
import polars as pl

    # web specific
import json, lxml, bs4

    # plotting
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt


''' Potentially useful future libraries

polars, duckdb	Processing or querying the larger extracted tables
statsmodels	Regression, statistical inference, uncertainty analysis
imagehash	Exploring near-duplicate photographs
scikit-image	Filters, image measurements, classical image-processing baselines
torch, torchvision	Pretrained neural networks and training experiments
pytest, ruff	Maintaining the reusable ingestion scripts
'''
# Out:
# ' Potentially useful future libraries\n\npolars, duckdb\tProcessing or querying the larger extracted tables\nstatsmodels\tRegression, statistical inference, uncertainty analysis\nimagehash\tExploring near-duplicate photographs\nscikit-image\tFilters, image measurements, classical image-processing baselines\ntorch, torchvision\tPretrained neural networks and training experiments\npytest, ruff\tMaintaining the reusable ingestion scripts\n'

# %%
ARCHIVE_DIR = os.getenv("archive_directory")
