# %%
import pandas as pd

file_path = 'C:/Users/ben.pharris/Documents/GitHub/project-dev/FunctionalEstimation/data/Boost_Media_Tables.xlsx'

#Extract Sheet Names
sheets_dict = pd.read_excel(file_path, sheet_name=None)

# %%
for name, df in sheets_dict.items():
    print(f"{name}: {df.shape}")
# Out:
# AH0012_OOH_PLACEMENT_DATA_4Q24: (639, 15)
# AH0012_OOH_PLACEMENT_DATA_4Q24_: (1016, 14)
# AH001_OOH_PLACEMENT_DATA_4Q24_1: (39123, 9)
# AL0001_DAILY_MARKET_SPEND: (11949, 10)
# AL0001_DAILY_MARKET_SPEND_HIST: (23537, 10)
# AL0001_DAILY_STORE_SPEND_HIST: (17461, 9)
# AL0001_DIGITAL: (26, 9)
# AL0001_DIGITAL_HIST: (110, 9)
# AL0001_DTR_EVENTS: (540, 13)
# AL0001_DTR_EVENTS_HIST: (819, 13)
# AL0001_HYPERLOCAL_SPEND_MARKET_: (204, 7)
# AL0001_HYPERLOCAL_SPEND_STORE_L: (1347, 7)

# %%
ooh_med = sheets_dict['AH0012_OOH_PLACEMENT_DATA_4Q24_']

# %%
dtr_small = sheets_dict['AL0001_DTR_EVENTS']
dtr_med = sheets_dict['AL0001_DTR_EVENTS_HIST']

# %%
ooh_large = sheets_dict['AH001_OOH_PLACEMENT_DATA_4Q24_1']
